# %%
import pandas as pd

# %%
fund = pd.read_csv("../data/raw/01_fund_master.csv")
print(fund.head())

# %%
print(fund.columns)

# %%
print("========== FUND MASTER SUMMARY ==========\n")

print("Total Rows :", fund.shape[0])
print("Total Columns :", fund.shape[1])

print("\nColumn Names")
print(fund.columns.tolist())

# %%
print("Unique Fund Houses\n")
print(fund["fund_house"].unique())

print("\nTotal Fund Houses :", fund["fund_house"].nunique())

# %%
print("Unique Categories\n")
print(fund["category"].unique())

print("\nTotal Categories :", fund["category"].nunique())

# %%
print("Unique Sub Categories\n")
print(fund["sub_category"].unique())

print("\nTotal Sub Categories :", fund["sub_category"].nunique())

# %%
print("Unique Risk Grades\n")
print(fund["risk_grade"].unique())

print("\nTotal Risk Grades :", fund["risk_grade"].nunique())
